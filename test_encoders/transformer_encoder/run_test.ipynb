# %%
import tensorflow as tf
import numpy as np

import sys
sys.path.append('../..')

from transformer_encoder import MLMTransformerEncoder
from mlm_dataset.mlm_dataset_generator import MLMDatasetGenerator

# %%
# MLM dataset for training
mlm_dataset_generator = MLMDatasetGenerator('../../dataset/resume_dataset.csv')
mlm_dataset = mlm_dataset_generator.generateMLMDataset(256)

# Initialize a Tokenizer and fit on text data
tokenizer = tf.keras.preprocessing.text.Tokenizer(oov_token='[OOV]')
tokenizer.fit_on_texts(mlm_dataset_generator.getVocubulary())

# check how many words are in the dataset (currently: 37032)
# print(list(tokenizer.word_index.keys()))

# %%
# MLM dataset checker
inputs, labels = mlm_dataset[0]

print(inputs[121], labels[121])
print(inputs[122], labels[122])

# for index, row in enumerate(inputs):
#     if(row.count('[MASK]') != len(labels[index])):
#         print(index, row, labels[index])
# Out:
# ['policy', '[MASK]'] ['development']
# ['web', 'page', '[MASK]'] ['development']

# %%
# Usage example with original Transformer hyperparameters
num_layers = 6
d_model = 512
num_heads = 8
dff = 2048
input_vocab_size = 40000
maximum_position_encoding = 10000

model = MLMTransformerEncoder(num_layers, d_model, num_heads, dff, input_vocab_size, maximum_position_encoding)
dummy_input = [tf.keras.Input(shape=(None,)), tf.keras.Input(shape=(None,))]
model(dummy_input)

# Define an optimizer (e.g., Adam)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# Define a loss function (e.g., categorical cross-entropy for classification)
loss_function = tf.keras.losses.CategoricalCrossentropy()

# %%
import time

# Define a training loop
def train_step(inputs_batch, labels_batch):
    start_time = time.time()

    total_loss = 0.0
    gradients_accumulator = [tf.zeros_like(var) for var in model.trainable_variables]

    counter = 0
    for inputs, labels in zip(inputs_batch, labels_batch):
        with tf.GradientTape() as tape:
            # create one-hot encoded mask and get the indices
            mask =[[]]
            token_indices = []
            for index, token in enumerate(inputs):
                if token == '[MASK]':
                    mask[0].append(0)
                    token_indices.append(index)
                else: 
                    mask[0].append(1)
            mask = tf.cast(mask, tf.float32)
            # tokenize inputs
            input_ids = tf.cast(tokenizer.texts_to_sequences([inputs]), tf.float32)
            # tokenize labels
            token_ids = tokenizer.texts_to_sequences(labels)
            # create array of zeroes with dimension [sequence_length, input_vocab_size]
            tokenized_labels = np.zeros((len(inputs), input_vocab_size))
            # change the [masked_token_index, token_id] to ones
            for index, token_index in enumerate(token_indices):
                tokenized_labels[token_index, token_ids[index]] = 1
            tokenized_labels = tf.constant(tokenized_labels, dtype=tf.float32)

            # print('\n> INPUTS')
            # print(input_ids)
            # print(mask)

            predictions = model([input_ids, mask], training=False)[0]

            # masked_token_indices = []
            # for index, binary in enumerate(mask[0]):
            #     if (binary == 0):
            #         masked_token_indices.append(index)

            # filtered_prediction = tf.gather(predictions, masked_token_indices, axis=0)
            # filtered_labels = tf.gather(tokenized_labels, masked_token_indices, axis=0)

            predicted_token = []
            for row in predictions.numpy():
                if (row[0] > 0):
                    predicted_token.append(np.argmax(row))

            # tokenized_labels = tf.nn.softmax(tokenized_labels)
            # predictions = tf.nn.softmax(predictions)

            # print('\n> LABELS')
            # print(tokenized_labels)
            # print('\n> PREDICTIONS')
            # print(predictions)

            loss = loss_function(tokenized_labels, predictions)
            # print('\n> LOSS')
            # print(loss)
        
        gradients = tape.gradient(loss, model.trainable_variables)
        # print('GRADIENTS')
        # print(gradients)

        gradients_accumulator = [(grad_accum + grad) / 2 for grad_accum, grad in zip(gradients_accumulator, gradients)]
        total_loss += loss

        print('Seq ' + str(counter) + ', Loss = ' + str(loss) + ', Predicted Token = ' + str(predicted_token) + ', True Token = ' + str(token_ids))
        counter += 1

    # gradients_avg = [grad / len(inputs_batch) for grad in gradients_accumulator]
    
    optimizer.apply_gradients(zip(gradients_accumulator, model.trainable_variables))

    return total_loss / len(inputs_batch), str(time.time() - start_time)

# %%
# Example of usage in the training loop
num_epochs = 10
for epoch in range(num_epochs):
    batch_counter = 0
    for inputs_batch, labels_batch in mlm_dataset:  # Provide training data
        loss, elapsed_time = train_step(inputs_batch, labels_batch)
        # Log or print the loss for monitoring
        print('Epoch ' + str(epoch) + ', Batch ' + str(batch_counter) + ', Loss = ' + str(loss) + ', Elapsed Time: ' + elapsed_time + '\n\n\n')
        batch_counter += 1
# Out:
# Seq 0, Loss = tf.Tensor(2.6974745, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[761]]
# Seq 1, Loss = tf.Tensor(5.3978014, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[761]]
# Seq 2, Loss = tf.Tensor(2.1393628, shape=(), dtype=float32), Predicted Token = [25263, 21427, 34827], True Token = [[826], [31], [7]]
# Seq 3, Loss = tf.Tensor(1.8511932, shape=(), dtype=float32), Predicted Token = [34827, 34827, 9466], True Token = [[8085], [1777], [16]]
# Seq 4, Loss = tf.Tensor(2.631157, shape=(), dtype=float32), Predicted Token = [32975], True Token = [[294]]
# Seq 5, Loss = tf.Tensor(5.3113327, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[11]]
# Seq 6, Loss = tf.Tensor(5.3812966, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[2384]]
# Seq 7, Loss = tf.Tensor(3.5014212, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[948]]
# Seq 8, Loss = tf.Tensor(3.539038, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[22]]
# Seq 9, Loss = tf.Tensor(10.572788, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[305, 2141]]
# Seq 10, Loss = tf.Tensor(3.473216, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[55]]
# Seq 11, Loss = tf.Tensor(2.1169105, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[3910]]
# Seq 12, Loss = tf.Tensor(2.1166568, shape=(), dtype=float32), Predicted Token = [25263, 21427], True Token = [[255], [1731]]
# Seq 13, Loss = tf.Tensor(1.7606825, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[133]]
# Seq 14, Loss = tf.Tensor(2.3627102, shape=(), dtype=float32), Predicted Token = [6250, 8080], True Token = [[6], [46]]
# Seq 15, Loss = tf.Tensor(5.2731066, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[14024]]
# Seq 16, Loss = tf.Tensor(5.327172, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[8524]]
# Seq 17, Loss = tf.Tensor(3.6106033, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[4481]]
# Seq 18, Loss = tf.Tensor(1.5995986, shape=(), dtype=float32), Predicted Token = [21427, 34827, 34827], True Token = [[7], [15], [1373]]
# Seq 19, Loss = tf.Tensor(2.592371, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[183]]
# Seq 20, Loss = tf.Tensor(5.3978014, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[761]]
# Seq 21, Loss = tf.Tensor(1.6923203, shape=(), dtype=float32), Predicted Token = [21427, 34827, 34827], True Token = [[2], [769], [727]]
# Seq 22, Loss = tf.Tensor(2.9711168, shape=(), dtype=float32), Predicted Token = [25263, 6250], True Token = [[1831], [4918]]
# Seq 23, Loss = tf.Tensor(1.8232893, shape=(), dtype=float32), Predicted Token = [21427, 21427, 34827, 34827, 180], True Token = [[120], [1633], [256], [159], [79]]
# Seq 24, Loss = tf.Tensor(2.388104, shape=(), dtype=float32), Predicted Token = [25263, 21427], True Token = [[7749], [431]]
# Seq 25, Loss = tf.Tensor(1.5888777, shape=(), dtype=float32), Predicted Token = [34827, 34827, 9466], True Token = [[256], [120], [2196]]
# Seq 26, Loss = tf.Tensor(5.2666826, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[211]]
# Seq 27, Loss = tf.Tensor(1.6422023, shape=(), dtype=float32), Predicted Token = [21427, 34827], True Token = [[32], [812]]
# Seq 28, Loss = tf.Tensor(1.783775, shape=(), dtype=float32), Predicted Token = [6250, 34827], True Token = [[5], [1353]]
# Seq 29, Loss = tf.Tensor(2.2539725, shape=(), dtype=float32), Predicted Token = [21427, 21427, 34827], True Token = [[386], [48], [467]]
# Seq 30, Loss = tf.Tensor(1.7637382, shape=(), dtype=float32), Predicted Token = [21427, 8080], True Token = [[52], [1658]]
# Seq 31, Loss = tf.Tensor(2.3176143, shape=(), dtype=float32), Predicted Token = [21427, 34827, 34827], True Token = [[1089], [3], [32]]
# Seq 32, Loss = tf.Tensor(2.5443065, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[176]]
# Seq 33, Loss = tf.Tensor(1.7631592, shape=(), dtype=float32), Predicted Token = [21427, 34827, 9466], True Token = [[5], [7204], [21841]]
# Seq 34, Loss = tf.Tensor(1.6962292, shape=(), dtype=float32), Predicted Token = [34827, 21724, 13754, 13754], True Token = [[7], [300], [148], [363]]
# Seq 35, Loss = tf.Tensor(1.893927, shape=(), dtype=float32), Predicted Token = [25263, 6250, 34827, 21724, 13754], True Token = [[277], [3], [13], [176], [298]]
# Seq 36, Loss = tf.Tensor(3.5342638, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[133]]
# Seq 37, Loss = tf.Tensor(1.8428394, shape=(), dtype=float32), Predicted Token = [34827, 34827, 21724], True Token = [[2], [166], [175]]
# Seq 38, Loss = tf.Tensor(2.0102298, shape=(), dtype=float32), Predicted Token = [21427, 34827, 180, 13754], True Token = [[146], [5], [2], [20]]
# Seq 39, Loss = tf.Tensor(2.1174297, shape=(), dtype=float32), Predicted Token = [21427, 21427], True Token = [[2], [793]]
# Seq 40, Loss = tf.Tensor(1.9742725, shape=(), dtype=float32), Predicted Token = [6250, 8080, 34827], True Token = [[2], [391], [2]]
# Seq 41, Loss = tf.Tensor(1.7681072, shape=(), dtype=float32), Predicted Token = [6250, 8080, 34827], True Token = [[2], [110], [290]]
# Seq 42, Loss = tf.Tensor(2.7085419, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[32]]
# Seq 43, Loss = tf.Tensor(1.7697138, shape=(), dtype=float32), Predicted Token = [21427, 34827], True Token = [[108], [166]]
# Seq 44, Loss = tf.Tensor(2.396932, shape=(), dtype=float32), Predicted Token = [25263, 34827], True Token = [[44], [569]]
# Seq 45, Loss = tf.Tensor(1.9643657, shape=(), dtype=float32), Predicted Token = [34827, 34827, 9466], True Token = [[16], [5795], [115]]
# Seq 46, Loss = tf.Tensor(2.2738163, shape=(), dtype=float32), Predicted Token = [25263, 21427, 21427], True Token = [[10306], [16], [20]]
# Seq 47, Loss = tf.Tensor(2.7102947, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[4481]]
# Seq 48, Loss = tf.Tensor(5.401312, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[996]]
# Seq 49, Loss = tf.Tensor(3.6163683, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[357]]
# Seq 50, Loss = tf.Tensor(5.308121, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[17]]
# Seq 51, Loss = tf.Tensor(5.3829136, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[149]]
# Seq 52, Loss = tf.Tensor(5.308121, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[17]]
# Seq 53, Loss = tf.Tensor(5.2451572, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[375]]
# Seq 54, Loss = tf.Tensor(3.5124977, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[84]]
# Seq 55, Loss = tf.Tensor(3.4859018, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[530]]
# Seq 56, Loss = tf.Tensor(2.647593, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[21842]]
# Seq 57, Loss = tf.Tensor(2.6868796, shape=(), dtype=float32), Predicted Token = [6250, 8080], True Token = [[21843], [7205]]
# Seq 58, Loss = tf.Tensor(1.731222, shape=(), dtype=float32), Predicted Token = [25263, 21427, 34827, 13754, 19497, 33533, 36941, 18141], True Token = [[68], [25], [54], [256], [176], [300], [338], [1325]]
# Seq 59, Loss = tf.Tensor(2.1488867, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[219]]
# Seq 60, Loss = tf.Tensor(1.9600962, shape=(), dtype=float32), Predicted Token = [8080, 34827], True Token = [[32], [103]]
# Seq 61, Loss = tf.Tensor(2.1488867, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[219]]
# Seq 62, Loss = tf.Tensor(1.7450131, shape=(), dtype=float32), Predicted Token = [6250, 34827], True Token = [[75], [485]]
# Seq 63, Loss = tf.Tensor(2.0134091, shape=(), dtype=float32), Predicted Token = [34827, 34827, 26676], True Token = [[65], [19], [938]]
# Seq 64, Loss = tf.Tensor(3.1619322, shape=(), dtype=float32), Predicted Token = [8080, 34827], True Token = [[12, 2838], [2928]]
# Seq 65, Loss = tf.Tensor(1.754414, shape=(), dtype=float32), Predicted Token = [6250, 8080], True Token = [[1548], [1461]]
# Seq 66, Loss = tf.Tensor(1.6450659, shape=(), dtype=float32), Predicted Token = [34827, 34827], True Token = [[14], [842]]
# Seq 67, Loss = tf.Tensor(1.982301, shape=(), dtype=float32), Predicted Token = [25263, 6250, 34827], True Token = [[376], [10], [18]]
# Seq 68, Loss = tf.Tensor(2.1059232, shape=(), dtype=float32), Predicted Token = [21427, 34827], True Token = [[702], [495]]
# Seq 69, Loss = tf.Tensor(3.033003, shape=(), dtype=float32), Predicted Token = [25263, 21427], True Token = [[356], [1430]]
# Seq 70, Loss = tf.Tensor(2.2775512, shape=(), dtype=float32), Predicted Token = [6250, 6250, 34827], True Token = [[480], [24], [2]]
# Seq 71, Loss = tf.Tensor(2.1125033, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[2]]
# Seq 72, Loss = tf.Tensor(2.094083, shape=(), dtype=float32), Predicted Token = [6250, 21427, 34827], True Token = [[1501], [919], [212]]
# Seq 73, Loss = tf.Tensor(1.6303878, shape=(), dtype=float32), Predicted Token = [6250, 21427], True Token = [[1778], [2]]
# Seq 74, Loss = tf.Tensor(2.6610348, shape=(), dtype=float32), Predicted Token = [6250, 21427], True Token = [[51], [552]]
# Seq 75, Loss = tf.Tensor(2.7036552, shape=(), dtype=float32), Predicted Token = [21427, 34827], True Token = [[2], [142]]
# Seq 76, Loss = tf.Tensor(1.5995893, shape=(), dtype=float32), Predicted Token = [6250, 34827, 180], True Token = [[9], [3], [236]]
# Seq 77, Loss = tf.Tensor(1.593186, shape=(), dtype=float32), Predicted Token = [21724, 9466, 25307], True Token = [[32], [2], [169]]
# Seq 78, Loss = tf.Tensor(2.1427472, shape=(), dtype=float32), Predicted Token = [21427, 34827, 34827], True Token = [[11], [3], [9]]
# Seq 79, Loss = tf.Tensor(1.769153, shape=(), dtype=float32), Predicted Token = [34827, 34827], True Token = [[237], [85]]
# Seq 80, Loss = tf.Tensor(1.776512, shape=(), dtype=float32), Predicted Token = [6250, 34827], True Token = [[533], [14]]
# Seq 81, Loss = tf.Tensor(2.6771064, shape=(), dtype=float32), Predicted Token = [32975], True Token = [[219]]
# Seq 82, Loss = tf.Tensor(1.9831269, shape=(), dtype=float32), Predicted Token = [6250, 34827, 34827], True Token = [[397], [2385], [752]]
# Seq 83, Loss = tf.Tensor(2.6535647, shape=(), dtype=float32), Predicted Token = [6250, 34827], True Token = [[2], [1389]]
# Seq 84, Loss = tf.Tensor(2.2557652, shape=(), dtype=float32), Predicted Token = [6250, 8080, 34827], True Token = [[556], [17], [841]]
# Seq 85, Loss = tf.Tensor(2.3792837, shape=(), dtype=float32), Predicted Token = [6250, 34827], True Token = [[32], [2]]
# Seq 86, Loss = tf.Tensor(2.0864942, shape=(), dtype=float32), Predicted Token = [6250, 34827], True Token = [[2], [293]]
# Seq 87, Loss = tf.Tensor(2.0405583, shape=(), dtype=float32), Predicted Token = [21427, 8080, 34827, 10843], True Token = [[885], [44], [730], [60]]
# Seq 88, Loss = tf.Tensor(2.372805, shape=(), dtype=float32), Predicted Token = [6250, 21427], True Token = [[32], [1659]]
# Seq 89, Loss = tf.Tensor(1.7650394, shape=(), dtype=float32), Predicted Token = [6250, 34827], True Token = [[706], [132]]
# Seq 90, Loss = tf.Tensor(2.1181607, shape=(), dtype=float32), Predicted Token = [21427, 8080], True Token = [[123], [15]]
# Seq 91, Loss = tf.Tensor(3.5623639, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[1059]]
# Seq 92, Loss = tf.Tensor(1.7679769, shape=(), dtype=float32), Predicted Token = [21427], True Token = [[4]]
# Seq 93, Loss = tf.Tensor(2.1071184, shape=(), dtype=float32), Predicted Token = [6250, 34827], True Token = [[80], [2]]
# Seq 94, Loss = tf.Tensor(1.757671, shape=(), dtype=float32), Predicted Token = [21427, 21427], True Token = [[10], [4]]
# Seq 95, Loss = tf.Tensor(3.0424335, shape=(), dtype=float32), Predicted Token = [6250, 21427], True Token = [[28], [552]]
# Seq 96, Loss = tf.Tensor(1.9337621, shape=(), dtype=float32), Predicted Token = [21427, 34827], True Token = [[49], [279]]
# Seq 97, Loss = tf.Tensor(1.9549816, shape=(), dtype=float32), Predicted Token = [6250, 34827], True Token = [[3], [52]]
# Seq 98, Loss = tf.Tensor(1.931866, shape=(), dtype=float32), Predicted Token = [6250, 6250], True Token = [[52], [3569]]
# Seq 99, Loss = tf.Tensor(1.6169968, shape=(), dtype=float32), Predicted Token = [21427, 34827], True Token = [[313], [475]]
# Seq 100, Loss = tf.Tensor(2.2783551, shape=(), dtype=float32), Predicted Token = [6250, 34827, 34827], True Token = [[92], [3649], [144]]
# Seq 101, Loss = tf.Tensor(2.271642, shape=(), dtype=float32), Predicted Token = [21427, 34827, 21724], True Token = [[1067], [3837], [8525]]
# Seq 102, Loss = tf.Tensor(1.7759844, shape=(), dtype=float32), Predicted Token = [34827, 34827], True Token = [[601], [15]]
# Seq 103, Loss = tf.Tensor(1.6487973, shape=(), dtype=float32), Predicted Token = [25263, 34827], True Token = [[1560], [3]]
# Seq 104, Loss = tf.Tensor(1.6665946, shape=(), dtype=float32), Predicted Token = [21427, 34827, 9466], True Token = [[12], [4], [9]]
# Seq 105, Loss = tf.Tensor(1.7836652, shape=(), dtype=float32), Predicted Token = [25263, 21724, 13754, 13754, 33533, 28136], True Token = [[3570], [1072], [238], [4668], [5516], [2084]]
# Seq 106, Loss = tf.Tensor(3.5345762, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[4]]
# Seq 107, Loss = tf.Tensor(2.6319969, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[75]]
# Seq 108, Loss = tf.Tensor(3.51041, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[2930]]
# Seq 109, Loss = tf.Tensor(3.539423, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[4]]
# Seq 110, Loss = tf.Tensor(5.2765937, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[4267]]
# Seq 111, Loss = tf.Tensor(2.6550033, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[2389]]
# Seq 112, Loss = tf.Tensor(1.7601527, shape=(), dtype=float32), Predicted Token = [25263, 34827, 9466, 13754, 13754, 18141, 723, 723, 18141], True Token = [[940], [147], [1335], [132], [1430], [311], [47], [479], [104]]
# Seq 113, Loss = tf.Tensor(5.303685, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[164]]
# Seq 114, Loss = tf.Tensor(1.7928785, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[113]]
# Seq 115, Loss = tf.Tensor(2.6238544, shape=(), dtype=float32), Predicted Token = [21427, 8080], True Token = [[191], [169]]
# Seq 116, Loss = tf.Tensor(3.0374303, shape=(), dtype=float32), Predicted Token = [25263, 8080], True Token = [[8], [131]]
# Seq 117, Loss = tf.Tensor(3.0280325, shape=(), dtype=float32), Predicted Token = [21427, 8080], True Token = [[7], [16611]]
# Seq 118, Loss = tf.Tensor(3.5787508, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[4033]]
# Seq 119, Loss = tf.Tensor(5.2919993, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[22]]
# Seq 120, Loss = tf.Tensor(5.3231344, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[1016]]
# Seq 121, Loss = tf.Tensor(5.2927637, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[22]]
# Seq 122, Loss = tf.Tensor(3.5385587, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[22]]
# Seq 123, Loss = tf.Tensor(1.8326137, shape=(), dtype=float32), Predicted Token = [21427, 21724, 180, 180, 13754], True Token = [[2741], [749], [5], [135], [4]]
# Seq 124, Loss = tf.Tensor(5.383476, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[29]]
# Seq 125, Loss = tf.Tensor(1.7617686, shape=(), dtype=float32), Predicted Token = [25263, 34827, 180, 13754, 19497, 33533, 6250], True Token = [[654], [4], [1645], [1280], [5], [10307], [1311]]
# Seq 126, Loss = tf.Tensor(1.641742, shape=(), dtype=float32), Predicted Token = [21427, 21427, 180, 13754, 19497, 33533, 6250], True Token = [[9], [146], [71], [73], [86], [5], [325]]
# Seq 127, Loss = tf.Tensor(1.776295, shape=(), dtype=float32), Predicted Token = [25263, 34827, 9466, 180, 13754, 13754], True Token = [[161], [137], [1779], [3303], [113], [37]]
# Seq 128, Loss = tf.Tensor(1.7015258, shape=(), dtype=float32), Predicted Token = [25263, 34827, 9466], True Token = [[27], [452], [1049]]
# Seq 129, Loss = tf.Tensor(2.2729578, shape=(), dtype=float32), Predicted Token = [21427, 34827, 34827], True Token = [[5269], [653], [474]]
# Seq 130, Loss = tf.Tensor(1.6319283, shape=(), dtype=float32), Predicted Token = [25263, 34827], True Token = [[1083], [11]]
# Seq 131, Loss = tf.Tensor(1.8372494, shape=(), dtype=float32), Predicted Token = [21427, 13754, 13754, 13754, 19497, 6250, 723], True Token = [[299], [2], [3], [32], [2], [4], [86]]
# Seq 132, Loss = tf.Tensor(1.6417634, shape=(), dtype=float32), Predicted Token = [34827, 9466, 25307, 13754, 33533], True Token = [[35], [413], [555], [145], [1810]]
# Seq 133, Loss = tf.Tensor(1.8940114, shape=(), dtype=float32), Predicted Token = [34827, 34827, 34827], True Token = [[152], [3], [6477]]
# Seq 134, Loss = tf.Tensor(2.0989401, shape=(), dtype=float32), Predicted Token = [8080, 34827, 34827], True Token = [[571], [2], [6]]
# Seq 135, Loss = tf.Tensor(1.759174, shape=(), dtype=float32), Predicted Token = [6250, 8080], True Token = [[912], [5]]
# Seq 136, Loss = tf.Tensor(5.303685, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[164]]
# Seq 137, Loss = tf.Tensor(2.2459528, shape=(), dtype=float32), Predicted Token = [21427, 34827, 34827], True Token = [[540], [205], [1634]]
# Seq 138, Loss = tf.Tensor(1.9726483, shape=(), dtype=float32), Predicted Token = [6250, 21427, 21724], True Token = [[679], [907], [21]]
# Seq 139, Loss = tf.Tensor(2.0726898, shape=(), dtype=float32), Predicted Token = [6250, 34827], True Token = [[111], [104]]
# Seq 140, Loss = tf.Tensor(2.104095, shape=(), dtype=float32), Predicted Token = [25263, 34827, 34827], True Token = [[82], [12], [2]]
# Seq 141, Loss = tf.Tensor(1.6709733, shape=(), dtype=float32), Predicted Token = [21427, 34827, 34827], True Token = [[165], [11], [1479]]
# Seq 142, Loss = tf.Tensor(2.0049157, shape=(), dtype=float32), Predicted Token = [21427, 34827, 21724], True Token = [[5], [200], [4]]
# Seq 143, Loss = tf.Tensor(5.181444, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[183]]
# Seq 144, Loss = tf.Tensor(1.5876238, shape=(), dtype=float32), Predicted Token = [6250, 34827], True Token = [[1780], [43]]
# Seq 145, Loss = tf.Tensor(1.9280692, shape=(), dtype=float32), Predicted Token = [6250, 21427, 21724, 25307], True Token = [[406], [3751], [135], [7]]
# Seq 146, Loss = tf.Tensor(1.6221293, shape=(), dtype=float32), Predicted Token = [6250, 34827, 34827, 38621, 6250, 6250], True Token = [[183], [2], [1131], [370], [1097], [921]]
# Seq 147, Loss = tf.Tensor(1.8680849, shape=(), dtype=float32), Predicted Token = [6250, 8080, 34827, 26676, 25307, 38621], True Token = [[307], [2], [1312], [325], [6], [12]]
# Seq 148, Loss = tf.Tensor(1.6512085, shape=(), dtype=float32), Predicted Token = [21427, 21427, 34827, 34827, 21724, 9466, 13754], True Token = [[5021], [2], [1419], [7], [121], [90], [1934]]
# Seq 149, Loss = tf.Tensor(1.6661049, shape=(), dtype=float32), Predicted Token = [34827, 34827, 25307], True Token = [[9], [5], [1367]]
# Seq 150, Loss = tf.Tensor(2.6059039, shape=(), dtype=float32), Predicted Token = [21427], True Token = [[2443]]
# Seq 151, Loss = tf.Tensor(2.640285, shape=(), dtype=float32), Predicted Token = [6250, 8080], True Token = [[1634], [6]]
# Seq 152, Loss = tf.Tensor(2.005383, shape=(), dtype=float32), Predicted Token = [21427, 34827, 21724], True Token = [[76], [14], [13]]
# Seq 153, Loss = tf.Tensor(1.8105093, shape=(), dtype=float32), Predicted Token = [21427], True Token = [[14]]
# Seq 154, Loss = tf.Tensor(1.9892966, shape=(), dtype=float32), Predicted Token = [25263, 8080, 34827, 9466], True Token = [[571], [66], [160], [13]]
# Seq 155, Loss = tf.Tensor(1.7739233, shape=(), dtype=float32), Predicted Token = [6250, 34827], True Token = [[6], [286]]
# Seq 156, Loss = tf.Tensor(1.7209957, shape=(), dtype=float32), Predicted Token = [21427, 34827, 26676, 13754, 13754], True Token = [[74], [2], [2], [390], [102]]
# Seq 157, Loss = tf.Tensor(3.0450711, shape=(), dtype=float32), Predicted Token = [21427, 34827, 21724], True Token = [[662], [2313, 170], [208]]
# Seq 158, Loss = tf.Tensor(3.5055997, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[191]]
# Seq 159, Loss = tf.Tensor(1.9415028, shape=(), dtype=float32), Predicted Token = [21427, 21427], True Token = [[41], [76]]
# Seq 160, Loss = tf.Tensor(1.898623, shape=(), dtype=float32), Predicted Token = [6250, 34827], True Token = [[1479], [515]]
# Seq 161, Loss = tf.Tensor(1.7159077, shape=(), dtype=float32), Predicted Token = [21427, 34827, 21724, 25307, 13754], True Token = [[479], [2], [110], [154], [2961]]
# Seq 162, Loss = tf.Tensor(1.7508551, shape=(), dtype=float32), Predicted Token = [6250, 6250], True Token = [[13], [5]]
# Seq 163, Loss = tf.Tensor(2.1517289, shape=(), dtype=float32), Predicted Token = [25263, 21427, 34827], True Token = [[230], [3115], [2420]]
# Seq 164, Loss = tf.Tensor(1.771027, shape=(), dtype=float32), Predicted Token = [21427, 34827], True Token = [[14], [175]]
# Seq 165, Loss = tf.Tensor(3.5020525, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[100]]
# Seq 166, Loss = tf.Tensor(5.36508, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[3473]]
# Seq 167, Loss = tf.Tensor(3.5477574, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[11]]
# Seq 168, Loss = tf.Tensor(5.439973, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[3913]]
# Seq 169, Loss = tf.Tensor(5.3536243, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[541]]
# Seq 170, Loss = tf.Tensor(2.360545, shape=(), dtype=float32), Predicted Token = [21427, 34827], True Token = [[2702], [46]]
# Seq 171, Loss = tf.Tensor(3.5825245, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[206]]
# Seq 172, Loss = tf.Tensor(5.3127427, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[11]]
# Seq 173, Loss = tf.Tensor(5.439973, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[3913]]
# Seq 174, Loss = tf.Tensor(5.3536243, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[541]]
# Seq 175, Loss = tf.Tensor(1.766707, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[1629]]
# Seq 176, Loss = tf.Tensor(3.620505, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[1112]]
# Seq 177, Loss = tf.Tensor(2.1125093, shape=(), dtype=float32), Predicted Token = [21427], True Token = [[1246]]
# Seq 178, Loss = tf.Tensor(2.6608686, shape=(), dtype=float32), Predicted Token = [25263, 6250], True Token = [[4484], [636]]
# Seq 179, Loss = tf.Tensor(3.5456655, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[4486]]
# Seq 180, Loss = tf.Tensor(5.230794, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[1218]]
# Seq 181, Loss = tf.Tensor(5.3949695, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[1712]]
# Seq 182, Loss = tf.Tensor(5.291485, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[194]]
# Seq 183, Loss = tf.Tensor(5.2343354, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[2743]]
# Seq 184, Loss = tf.Tensor(5.1331367, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[808]]
# Seq 185, Loss = tf.Tensor(3.569665, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[540]]
# Seq 186, Loss = tf.Tensor(5.3099236, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[11]]
# Seq 187, Loss = tf.Tensor(5.3351126, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[6289]]
# Seq 188, Loss = tf.Tensor(5.2893715, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[1482]]
# Seq 189, Loss = tf.Tensor(1.7938561, shape=(), dtype=float32), Predicted Token = [21427], True Token = [[1742]]
# Seq 190, Loss = tf.Tensor(2.71497, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[1354]]
# Seq 191, Loss = tf.Tensor(5.3545017, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[140]]
# Seq 192, Loss = tf.Tensor(3.5385587, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[22]]
# Seq 193, Loss = tf.Tensor(5.177666, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[183]]
# Seq 194, Loss = tf.Tensor(1.8131638, shape=(), dtype=float32), Predicted Token = [25263, 34827, 13754, 33533, 18141, 28136, 723], True Token = [[689], [113], [56], [21], [724], [197], [54]]
# Seq 195, Loss = tf.Tensor(2.9975495, shape=(), dtype=float32), Predicted Token = [6250, 8080], True Token = [[2703], [2987]]
# Seq 196, Loss = tf.Tensor(3.0034719, shape=(), dtype=float32), Predicted Token = [6250, 8080], True Token = [[210], [360]]
# Seq 197, Loss = tf.Tensor(5.2787466, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[159]]
# Seq 198, Loss = tf.Tensor(2.6329374, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[2]]
# Seq 199, Loss = tf.Tensor(1.6285502, shape=(), dtype=float32), Predicted Token = [6250, 34827], True Token = [[16], [856]]
# Seq 200, Loss = tf.Tensor(1.8023628, shape=(), dtype=float32), Predicted Token = [21427], True Token = [[524]]
# Seq 201, Loss = tf.Tensor(2.1273396, shape=(), dtype=float32), Predicted Token = [21427, 34827], True Token = [[649], [431]]
# Seq 202, Loss = tf.Tensor(5.177666, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[183]]
# Seq 203, Loss = tf.Tensor(2.14109, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[573]]
# Seq 204, Loss = tf.Tensor(1.9226292, shape=(), dtype=float32), Predicted Token = [8080, 34827, 9466, 13754], True Token = [[1371], [1072], [115], [85]]
# Seq 205, Loss = tf.Tensor(1.6721215, shape=(), dtype=float32), Predicted Token = [21427, 21724, 9466], True Token = [[1262], [573], [10308]]
# Seq 206, Loss = tf.Tensor(2.1567981, shape=(), dtype=float32), Predicted Token = [21427, 21427, 21724], True Token = [[55], [1210], [431]]
# Seq 207, Loss = tf.Tensor(1.581705, shape=(), dtype=float32), Predicted Token = [34827, 9466, 180], True Token = [[18], [13], [1039]]
# Seq 208, Loss = tf.Tensor(3.5083017, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[16]]
# Seq 209, Loss = tf.Tensor(1.5731757, shape=(), dtype=float32), Predicted Token = [21427, 8080, 34827], True Token = [[16], [402], [4]]
# Seq 210, Loss = tf.Tensor(1.7610583, shape=(), dtype=float32), Predicted Token = [6250, 34827, 9466], True Token = [[2], [2], [3650]]
# Seq 211, Loss = tf.Tensor(1.6172377, shape=(), dtype=float32), Predicted Token = [21427, 8080], True Token = [[2196], [21]]
# Seq 212, Loss = tf.Tensor(2.1480002, shape=(), dtype=float32), Predicted Token = [25263, 6250], True Token = [[229], [62]]
# Seq 213, Loss = tf.Tensor(1.6307201, shape=(), dtype=float32), Predicted Token = [34827, 34827], True Token = [[6696], [3018]]
# Seq 214, Loss = tf.Tensor(2.100163, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[485]]
# Seq 215, Loss = tf.Tensor(2.689898, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[429]]
# Seq 216, Loss = tf.Tensor(1.7435368, shape=(), dtype=float32), Predicted Token = [25263, 21427, 21427, 13754, 13754, 6250, 723, 36941], True Token = [[838], [272], [6], [137], [3], [3], [770], [137]]
# Seq 217, Loss = tf.Tensor(3.5020525, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[100]]
# Seq 218, Loss = tf.Tensor(2.1355033, shape=(), dtype=float32), Predicted Token = [21427], True Token = [[117]]
# Seq 219, Loss = tf.Tensor(2.097359, shape=(), dtype=float32), Predicted Token = [21427], True Token = [[2704]]
# Seq 220, Loss = tf.Tensor(2.6622796, shape=(), dtype=float32), Predicted Token = [21427, 34827], True Token = [[8], [285]]
# Seq 221, Loss = tf.Tensor(2.6546717, shape=(), dtype=float32), Predicted Token = [21427, 8080], True Token = [[360], [69]]
# Seq 222, Loss = tf.Tensor(5.1865153, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[183]]
# Seq 223, Loss = tf.Tensor(5.263575, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[670]]
# Seq 224, Loss = tf.Tensor(5.177141, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[183]]
# Seq 225, Loss = tf.Tensor(3.4800892, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[101]]
# Seq 226, Loss = tf.Tensor(2.626342, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[215]]
# Seq 227, Loss = tf.Tensor(5.2553673, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[679]]
# Seq 228, Loss = tf.Tensor(2.6788852, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[4033]]
# Seq 229, Loss = tf.Tensor(5.342591, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[2962]]
# Seq 230, Loss = tf.Tensor(1.728402, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[183]]
# Seq 231, Loss = tf.Tensor(5.3262234, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[1098]]
# Seq 232, Loss = tf.Tensor(5.2216463, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[104]]
# Seq 233, Loss = tf.Tensor(5.3116846, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[117]]
# Seq 234, Loss = tf.Tensor(5.30538, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[117]]
# Seq 235, Loss = tf.Tensor(3.55283, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[117]]
# Seq 236, Loss = tf.Tensor(5.275135, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[978]]
# Seq 237, Loss = tf.Tensor(5.1457305, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[920]]
# Seq 238, Loss = tf.Tensor(5.303529, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[22]]
# Seq 239, Loss = tf.Tensor(5.4167137, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[79]]
# Seq 240, Loss = tf.Tensor(5.2918243, shape=(), dtype=float32), Predicted Token = [6250], True Token = [[22]]
# Seq 241, Loss = tf.Tensor(2.6745975, shape=(), dtype=float32), Predicted Token = [21427], True Token = [[11]]
# Seq 242, Loss = tf.Tensor(1.7478391, shape=(), dtype=float32), Predicted Token = [21427], True Token = [[6113]]
# Seq 243, Loss = tf.Tensor(2.370612, shape=(), dtype=float32), Predicted Token = [21427, 34827], True Token = [[128], [1813]]
# Seq 244, Loss = tf.Tensor(5.3573523, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[39]]
# Seq 245, Loss = tf.Tensor(5.2216206, shape=(), dtype=float32), Predicted Token = [25263], True Token = [[31]]
# Seq 246, Loss = tf.Tensor(1.7581967, shape=(), dtype=float32), Predicted Token = [21427, 21724, 9466, 180, 38621], True Token = [[6], [2550], [228], [4], [485]]
# Seq 247, Loss = tf.Tensor(1.9706793, shape=(), dtype=float32), Predicted Token = [6250, 21427, 21724], True Token = [[261], [1467], [2]]
# Seq 248, Loss = tf.Tensor(1.8566544, shape=(), dtype=float32), Predicted Token = [34827, 34827, 21724], True Token = [[390], [13], [223]]
# Seq 249, Loss = tf.Tensor(2.0839481, shape=(), dtype=float32), Predicted Token = [21427, 34827], True Token = [[115], [18]]
# Seq 250, Loss = tf.Tensor(2.2428455, shape=(), dtype=float32), Predicted Token = [21427, 34827, 34827], True Token = [[445], [2791], [223]]
# Seq 251, Loss = tf.Tensor(1.9339455, shape=(), dtype=float32), Predicted Token = [21427, 34827, 34827, 21724], True Token = [[102], [2], [4415], [216]]
# Seq 252, Loss = tf.Tensor(1.6205409, shape=(), dtype=float32), Predicted Token = [34827, 34827], True Token = [[223], [102]]
# Seq 253, Loss = tf.Tensor(2.68837, shape=(), dtype=float32), Predicted Token = [6250, 21427], True Token = [[162], [224]]
# Seq 254, Loss = tf.Tensor(1.6691549, shape=(), dtype=float32), Predicted Token = [6250, 8080, 21724], True Token = [[30], [7], [10]]
# Seq 255, Loss = tf.Tensor(1.9620649, shape=(), dtype=float32), Predicted Token = [21427, 21427, 34827, 34827, 13754], True Token = [[166], [344], [2], [11], [94]]
# Epoch 0, Batch 0, Loss = tf.Tensor(2.9423077, shape=(), dtype=float32), Elapsed Time: 264.98537850379944
#
#
#
# Seq 0, Loss = tf.Tensor(2.0010862, shape=(), dtype=float32), Predicted Token = [94, 2, 94, 94], True Token = [[1896], [101], [932], [513]]
# Seq 1, Loss = tf.Tensor(2.1995554, shape=(), dtype=float32), Predicted Token = [94, 94], True Token = [[7], [5]]
# Seq 2, Loss = tf.Tensor(1.5299227, shape=(), dtype=float32), Predicted Token = [94, 94], True Token = [[2385], [2]]
# Seq 3, Loss = tf.Tensor(1.6781907, shape=(), dtype=float32), Predicted Token = [94, 2, 94], True Token = [[2232], [8], [5]]
# Seq 4, Loss = tf.Tensor(3.5413408, shape=(), dtype=float32), Predicted Token = [94], True Token = [[183]]
# Seq 5, Loss = tf.Tensor(1.5938575, shape=(), dtype=float32), Predicted Token = [94, 2, 94, 94, 94, 94, 94], True Token = [[10], [27], [212], [136], [158], [3], [329]]
# Seq 6, Loss = tf.Tensor(1.6295453, shape=(), dtype=float32), Predicted Token = [94, 94, 94, 94], True Token = [[261], [701], [170], [37]]
# Seq 7, Loss = tf.Tensor(1.5720477, shape=(), dtype=float32), Predicted Token = [94, 2, 94, 94], True Token = [[174], [5], [2], [183]]
# Seq 8, Loss = tf.Tensor(1.7590528, shape=(), dtype=float32), Predicted Token = [2, 94, 94], True Token = [[183], [13], [17]]
# Seq 9, Loss = tf.Tensor(1.917292, shape=(), dtype=float32), Predicted Token = [94, 2, 94, 94, 94], True Token = [[841], [88], [61], [4], [2]]
# Seq 10, Loss = tf.Tensor(1.6915492, shape=(), dtype=float32), Predicted Token = [2, 94, 94, 94, 94], True Token = [[233], [3080], [98], [98], [8088]]
# Seq 11, Loss = tf.Tensor(2.0170872, shape=(), dtype=float32), Predicted Token = [94, 94, 94], True Token = [[2], [5], [532]]
# Seq 12, Loss = tf.Tensor(1.9464675, shape=(), dtype=float32), Predicted Token = [94, 2], True Token = [[73], [203]]
# Seq 13, Loss = tf.Tensor(1.963311, shape=(), dtype=float32), Predicted Token = [94, 94, 94, 94], True Token = [[9], [2], [395], [3]]
# Seq 14, Loss = tf.Tensor(1.6989497, shape=(), dtype=float32), Predicted Token = [94, 94, 2, 94], True Token = [[4], [2], [918], [633]]
# Seq 15, Loss = tf.Tensor(2.370616, shape=(), dtype=float32), Predicted Token = [94, 2], True Token = [[26], [21858]]
# Seq 16, Loss = tf.Tensor(2.2825701, shape=(), dtype=float32), Predicted Token = [94, 94, 94], True Token = [[140], [12], [22]]
# Seq 17, Loss = tf.Tensor(1.7162424, shape=(), dtype=float32), Predicted Token = [94, 94, 94, 94, 94], True Token = [[775], [301], [71], [342], [6114]]
# Seq 18, Loss = tf.Tensor(2.0468595, shape=(), dtype=float32), Predicted Token = [94, 2], True Token = [[10], [21]]
# Seq 19, Loss = tf.Tensor(1.914602, shape=(), dtype=float32), Predicted Token = [94, 94, 2, 94], True Token = [[73], [1130], [7], [2]]
# Seq 20, Loss = tf.Tensor(1.9194407, shape=(), dtype=float32), Predicted Token = [94, 94], True Token = [[20], [275]]
# Seq 21, Loss = tf.Tensor(1.7626978, shape=(), dtype=float32), Predicted Token = [94, 2], True Token = [[1875], [183]]
# Seq 22, Loss = tf.Tensor(1.5862451, shape=(), dtype=float32), Predicted Token = [94, 2, 2], True Token = [[5], [2], [778]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18972\1567218078.py in ?()
#       3 # Example of usage in the training loop
#       4 num_epochs = 10
#       5 for epoch in range(num_epochs):
# ----> 6     batch_counter = 0
#       7     for inputs_batch, labels_batch in mlm_dataset:  # Provide training data
#       8         loss, elapsed_time = train_step(inputs_batch, labels_batch)
#       9         # Log or print the loss for monitoring
#
# ~\AppData\Local\Temp\ipykernel_18972\3780568174.py in ?(inputs_batch, labels_batch)
#      57             # print(tokenized_labels)
#      58             # print('\n> PREDICTIONS')
#      59             # print(predictions)
#      60
# ---> 61             loss = loss_function(tokenized_labels, predictions)
#      62             # print('\n> LOSS')
#      63             # print(loss)
#      64
#
# d:\Applications\Python\Python39\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# d:\Applications\Python\Python39\lib\site-packages\keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1156                     )
#    1157                 if self._saved_model_inputs_spec is None:
#    1158                     self._set_save_spec(inputs, args, kwargs)
#    1159
# -> 1160                 return outputs
#
# d:\Applications\Python\Python39\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# d:\M3OW\School\BSCS 4-3\1st Sem\Thesis Writing 2\resume_checker\test_encoders\transformer_encoder\transformer_encoder.py in ?(self, inputs, training)
#      83
#      84         # Apply mask
#      85         masked_x = x * mask
#      86
# ---> 87         transformer_output = self.transformer_encoder(masked_x, training)
#      88
#      89         mask = tf.expand_dims(mask, axis=-1)
#      90
#
# d:\Applications\Python\Python39\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# d:\Applications\Python\Python39\lib\site-packages\keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1156                     )
#    1157                 if self._saved_model_inputs_spec is None:
#    1158                     self._set_save_spec(inputs, args, kwargs)
#    1159
# -> 1160                 return outputs
#
# d:\Applications\Python\Python39\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# d:\M3OW\School\BSCS 4-3\1st Sem\Thesis Writing 2\resume_checker\test_encoders\transformer_encoder\transformer_encoder.py in ?(self, x, training)
#      61
#      62         x = self.dropout(x, training=training)
#      63
#      64         for encoder_layer in self.encoder_layers:
# ---> 65             x = encoder_layer(x, training)
#      66
#      67         return x
#
# d:\Applications\Python\Python39\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# d:\Applications\Python\Python39\lib\site-packages\keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1156                     )
#    1157                 if self._saved_model_inputs_spec is None:
#    1158                     self._set_save_spec(inputs, args, kwargs)
#    1159
# -> 1160                 return outputs
#
# d:\Applications\Python\Python39\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# d:\M3OW\School\BSCS 4-3\1st Sem\Thesis Writing 2\resume_checker\test_encoders\transformer_encoder\transformer_encoder.py in ?(self, x, training)
#      26         out1 = self.layernorm1(x + attn_output)
#      27
#      28         ff_output = self.feed_forward(out1)
#      29         ff_output = self.dropout2(ff_output, training=training)
# ---> 30         out2 = self.layernorm2(out1 + ff_output)
#      31
#      32         return out2
#
# d:\Applications\Python\Python39\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# d:\Applications\Python\Python39\lib\site-packages\keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1156                     )
#    1157                 if self._saved_model_inputs_spec is None:
#    1158                     self._set_save_spec(inputs, args, kwargs)
#    1159
# -> 1160                 return outputs
#
# d:\Applications\Python\Python39\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# d:\Applications\Python\Python39\lib\site-packages\keras\src\layers\normalization\layer_normalization.py in ?(self, inputs)
#     293             scale, offset = _broadcast(self.gamma), _broadcast(self.beta)
#     294
#     295             # Compute layer normalization using the batch_normalization
#     296             # function.
# --> 297             outputs = tf.nn.batch_normalization(
#     298                 inputs,
#     299                 mean,
#     300                 variance,
#
# d:\Applications\Python\Python39\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# d:\Applications\Python\Python39\lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#    1265         if result is not OpDispatcher.NOT_SUPPORTED:
#    1266           return result
#    1267         else:
# -> 1268           raise
#
# d:\Applications\Python\Python39\lib\site-packages\tensorflow\python\ops\nn_impl.py in ?(x, mean, variance, offset, scale, variance_epsilon, name)
#    1594     if scale is not None:
#    1595       inv *= scale
#    1596     # Note: tensorflow/contrib/quantize/python/fold_batch_norms.py depends on
#    1597     # the precise order of ops that are generated by the expression below.
# -> 1598     return x * math_ops.cast(inv, x.dtype) + math_ops.cast(
#    1599         offset - mean * inv if offset is not None else -mean * inv, x.dtype)
#
# d:\Applications\Python\Python39\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# d:\Applications\Python\Python39\lib\site-packages\tensorflow\python\ops\math_ops.py in ?(x, y)
#    1491             return out
#    1492           except (TypeError, ValueError):
#    1493             raise e
#    1494         else:
# -> 1495           raise
#
# d:\Applications\Python\Python39\lib\site-packages\tensorflow\python\ops\math_ops.py in ?(x, y, name)
#    1874     new_vals = gen_sparse_ops.sparse_dense_cwise_mul(y.indices, y.values,
#    1875                                                      y.dense_shape, x, name)
#    1876     return sparse_tensor.SparseTensor(y.indices, new_vals, y.dense_shape)
#    1877   else:
# -> 1878     return multiply(x, y, name=name)
#
# d:\Applications\Python\Python39\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# d:\Applications\Python\Python39\lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#    1265         if result is not OpDispatcher.NOT_SUPPORTED:
#    1266           return result
#    1267         else:
# -> 1268           raise
#
# d:\Applications\Python\Python39\lib\site-packages\tensorflow\python\ops\math_ops.py in ?(x, y, name)
#     525
#     526    * InvalidArgumentError: When `x` and `y` have incompatible shapes or types.
#     527   """
#     528
# --> 529   return gen_math_ops.mul(x, y, name)
#
# d:\Applications\Python\Python39\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in ?(x, y, name)
#    7500       return _result
#    7501     except _core._NotOkStatusException as e:
#    7502       _ops.raise_from_not_ok_status(e, name)
#    7503     except _core._FallbackException:
# -> 7504       pass
#    7505     try:
#    7506       return mul_eager_fallback(
#    7507           x, y, name=name, ctx=_ctx)
#
# KeyboardInterrupt:

# %%
print(model.trainable_variables)
# Out:
# [<tf.Variable 'mlm_transformer_encoder/transformer_encoder/embedding/embeddings:0' shape=(40000, 512) dtype=float32, numpy=
# array([[-0.01588781,  0.01453067, -0.02597257, ...,  0.04620039,
#         -0.0454732 , -0.02524504],
#        [ 0.0347981 , -0.02962655,  0.04831713, ..., -0.00495056,
#         -0.01368779,  0.03826029],
#        [-0.01359411,  0.0312282 , -0.02915373, ..., -0.0338385 ,
# array([[ 0.00163678, -0.00167435, -0.0015817 , ...,  0.0016465 ,
#         -0.00163758,  0.00112807],
#        [-0.00153881, -0.00146821,  0.00138296, ..., -0.00160742,
#         -0.00163228, -0.00140559],
#        [ 0.00163634,  0.0016447 ,  0.0016352 , ...,  0.00153837,
#          0.00155418, -0.00159393],
#        ...,
#        [-0.00156066, -0.0016617 , -0.00111437, ...,  0.00158503,
#          0.00145004,  0.00162883],
#        [ 0.00155016,  0.00164857,  0.00162647, ..., -0.00169141,
#          0.00165357, -0.00161596],
#        [-0.00126029, -0.00134087,  0.00140664, ..., -0.00153963,
#          0.00167844, -0.00150613]], dtype=float32)>, <tf.Variable 'mlm_transformer_encoder/transformer_encoder/encoder/multi_head_attention/attention_output/kernel:0' shape=(8, 512, 512) dtype=float32, numpy=
# array([[[-0.02305093,  0.00725038, -0.01503666, ..., -0.02199401,
#          -0.00684905,  0.023113  ],
#         [ 0.02334854, -0.00293634, -0.00057498, ...,  0.01319503,
#           0.01499112, -0.00185518],
#         [-0.02757023,  0.02105291,  0.00201407, ..., -0.02778636,
#           0.01014968,  0.00539897],
#         ...,
#         [ 0.0031018 ,  0.02585335,  0.02153098, ..., -0.00062604,
#           0.02042694,  0.01810868],
#         [-0.01360561, -0.02012874, -0.02167466, ...,  0.02505645,
#           0.01250414,  0.02076258],
#         [ 0.00887778,  0.02583833,  0.00443619, ..., -0.02389879,
#          -0.00714983, -0.01488306]],
#
#        [[-0.00562267,  0.0147808 , -0.02483398, ..., -0.01499122,
#          -0.0166489 , -0.00566936],
#         [ 0.00549142, -0.00970417, -0.00912388, ...,  0.00731574,
#          -0.02200613,  0.01675498],
#         [-0.01499557, -0.00661495,  0.0074377 , ...,  0.01281182,
#          -0.01811107, -0.02371098],
#         ...,
#         [ 0.00818887, -0.01516891,  0.0260649 , ...,  0.00595514,
#          -0.01108593, -0.01562838],
#         [ 0.01219504,  0.01110221, -0.02002333, ...,  0.02374964,
#          -0.01362897,  0.0187872 ],
#         [-0.00917847,  0.00468978,  0.02572879, ...,  0.02275993,
#          -0.02225293, -0.02182993]],
#
#        [[-0.0171929 , -0.02724667, -0.01101856, ..., -0.0063916 ,
#           0.02109971, -0.00286378],
#         [ 0.00035385,  0.0231666 ,  0.00466871, ...,  0.00018106,
#          -0.0039995 ,  0.00184507],
#         [ 0.02055652, -0.00509231, -0.00711219, ..., -0.00443155,
#          -0.00843669,  0.00865836],
#         ...,
#         [ 0.0201201 , -0.02332492,  0.01936487, ..., -0.00698682,
#           0.022882  ,  0.01371998],
#         [ 0.01528953, -0.0217541 ,  0.00749451, ...,  0.001078  ,
#          -0.00980105, -0.02435947],
#         [-0.00472976,  0.00206101,  0.01034355, ...,  0.00857252,
#           0.01036429,  0.01235093]],
#
#        ...,
#
#        [[-0.00024864,  0.01105574, -0.01979614, ...,  0.01586433,
#          -0.02499319,  0.01696529],
#         [-0.01729278,  0.00665434,  0.02355589, ...,  0.00337914,
#          -0.02061238,  0.01436317],
#         [ 0.00221592, -0.00332689,  0.01210785, ..., -0.02636689,
#          -0.01727334,  0.01519113],
#         ...,
#         [-0.01641202, -0.02538864, -0.02402005, ..., -0.02289263,
#           0.02076173,  0.02648913],
#         [-0.01317174,  0.00899314, -0.02646926, ..., -0.00537161,
#           0.0121532 ,  0.01501794],
#         [-0.02331795, -0.01742602,  0.02761464, ..., -0.00138865,
#           0.01119944, -0.00607094]],
#
#        [[-0.02348739, -0.02522759,  0.00690747, ...,  0.00843675,
#           0.01600087, -0.00563077],
#         [-0.01538392,  0.00374361, -0.01529624, ..., -0.00921375,
#           0.01035122,  0.02109596],
#         [-0.01860443, -0.01520726, -0.00764422, ...,  0.02243354,
#           0.02259379, -0.00675499],
#         ...,
#         [-0.01336231,  0.01901049, -0.00961217, ..., -0.02342334,
#          -0.00939196, -0.0089262 ],
#         [ 0.01182648,  0.01532303,  0.00581453, ..., -0.02408754,
#           0.01542245, -0.01525791],
#         [ 0.00907553,  0.02239057, -0.0179404 , ..., -0.02679873,
#           0.00701077,  0.01069228]],
#
#        [[-0.0008099 , -0.00457716, -0.0100012 , ...,  0.01281463,
#          -0.02315751, -0.023416  ],
#         [-0.00924166,  0.01066321, -0.0132615 , ..., -0.00351568,
#           0.00042231, -0.00574024],
#         [-0.01389246, -0.01535534, -0.01091237, ...,  0.01237546,
#          -0.0180472 , -0.01170865],
#         ...,
#         [-0.02204865,  0.00947675, -0.02368576, ...,  0.00598269,
#           0.00969383,  0.02621034],
#         [ 0.02598764, -0.02384452, -0.01904826, ...,  0.00256629,
#          -0.0257512 ,  0.02563767],
#         [-0.00953347, -0.0219865 ,  0.00540449, ..., -0.01388087,
#          -0.02510664, -0.01868943]]], dtype=float32)>, <tf.Variable 'mlm_transformer_encoder/transformer_encoder/encoder/multi_head_attention/attention_output/bias:0' shape=(512,) dtype=float32, numpy=
# array([-1.03981234e-04,  1.54911354e-03, -1.01840356e-03,  1.44219946e-03,
#        -1.49841572e-03,  7.17290677e-04,  1.45487417e-03,  1.59906002e-03,
#        -1.66125945e-03,  1.42191770e-03, -1.66536402e-03,  1.64351217e-03,
#        -1.64982956e-03,  1.63821317e-03, -1.53493474e-03, -1.63648080e-03,
#        -1.65397837e-03, -1.67386397e-03,  1.51836616e-03,  1.70464837e-03,
#        -1.69474888e-03,  5.29975281e-04, -1.66550919e-03,  1.14910363e-03,
#         1.60980457e-03,  1.60038052e-03, -1.61806727e-03,  1.57049124e-03,
#         1.67059782e-03, -1.73457852e-03,  1.67232752e-03,  1.72309147e-03,
#        -1.67468784e-03,  1.60970713e-03,  1.63055316e-03, -1.65877468e-03,
#         1.64176023e-03, -1.20994437e-03, -1.61386549e-03, -1.66527671e-03,
#        -1.62456487e-03,  1.57049298e-03, -1.62265077e-03, -1.63680536e-03,
#         1.67075475e-03,  7.61326519e-04,  1.59388164e-03, -1.66055956e-03,
#        -1.62177940e-03,  1.52279704e-03,  1.68839679e-03,  1.62130385e-03,
#         1.43910339e-03,  1.64533942e-03, -1.49506773e-03, -1.68948644e-03,
#        -1.60116889e-03, -1.77791738e-03, -1.39323145e-03,  1.63625099e-03,
#        -1.59627176e-03, -1.54038472e-03, -1.63977745e-03,  1.66541000e-03,
#         1.42182480e-03,  1.57659990e-03, -1.65590132e-03, -1.67555513e-03,
#        -1.39861007e-03,  1.52815087e-03,  1.69362838e-03, -1.63711910e-03,
#        -1.68430596e-03,  1.67558878e-03,  1.28528639e-03,  1.43894390e-03],
#       dtype=float32)>, <tf.Variable 'dense/kernel:0' shape=(512, 2048) dtype=float32, numpy=
# array([[ 0.01181905, -0.01726966,  0.00806413, ...,  0.03720542,
#         -0.00499461, -0.04705228],
#        [-0.03132885,  0.00047648, -0.01532023, ..., -0.0035059 ,
#         -0.02950082,  0.04537559],
#        [-0.01666366, -0.04621501,  0.02562913, ...,  0.02876273,
#          0.02179612,  0.02268643],
#        ...,
#        [ 0.04092327,  0.02375806, -0.00865001, ..., -0.03644487,
#         -0.03608203,  0.04255795],
#        [ 0.01046701,  0.00170081,  0.00224907, ...,  0.02521604,
#          0.01828668, -0.03467022],
#        [ 0.03818274, -0.01864254, -0.04520544, ...,  0.0360086 ,
#          0.02015926, -0.04356121]], dtype=float32)>, <tf.Variable 'dense/bias:0' shape=(2048,) dtype=float32, numpy=
# array([-0.00066192,  0.00166884, -0.00072266, ..., -0.00088909,
#         0.00045082, -0.00137268], dtype=float32)>, <tf.Variable 'dense_1/kernel:0' shape=(2048, 512) dtype=float32, numpy=
# array([[ 0.02488815,  0.00680923,  0.00974574, ...,  0.00645995,
#          0.02942976,  0.04052647],
#        [ 0.00187758, -0.0460806 , -0.04291884, ..., -0.01642103,
#         -0.00262471, -0.04401388],
#        [ 0.0359775 ,  0.02776839,  0.03997813, ..., -0.04277235,
#          0.03856008, -0.00527161],
#        ...,
#        [-0.00752395,  0.04572918, -0.00914972, ..., -0.03462663,
#         -0.03789894, -0.00396767],
#        [-0.00159926,  0.04032575,  0.01110705, ...,  0.04014978,
#          0.00588292,  0.02572169],
#        [ 0.02097825,  0.01998417,  0.00491296, ...,  0.01017399,
#          0.0218663 , -0.03458035]], dtype=float32)>, <tf.Variable 'dense_1/bias:0' shape=(512,) dtype=float32, numpy=
# array([-1.4991283e-03,  1.3972097e-03, -1.4741247e-03,  1.5302475e-03,
#        -1.5410879e-03, -1.6926534e-03,  1.4146096e-03,  1.5661514e-03,
#        -1.6551346e-03, -1.6181706e-03, -1.6839220e-03,  1.6226748e-03,
#        -1.6722467e-03,  1.6283999e-03, -1.5739463e-03, -1.6654064e-03,
#        -1.5367292e-03, -1.6676072e-03,  1.4382733e-03,  1.6231947e-03,
#        -1.7331339e-03,  1.5146309e-03, -1.6981241e-03,  7.9843099e-05,
#         1.6365094e-03,  1.6257900e-03, -1.5969083e-03,  1.5342482e-03,
#         1.6991487e-03,  1.4616176e-03,  1.7063902e-03,  1.7017093e-03,
#        -1.7061809e-03, -1.6650404e-03,  1.6269576e-03, -1.6300846e-03,
