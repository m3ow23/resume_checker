# %%
import tensorflow as tf
import numpy as np

import sys
sys.path.append('../..')

from transformer_encoder import MLMTransformerEncoder
from mlm_dataset.mlm_dataset_generator import MLMDatasetGenerator

# %%
# MLM dataset for training
mlm_dataset_generator = MLMDatasetGenerator('../../dataset/resume_dataset.csv')
mlm_dataset = mlm_dataset_generator.generateMLMDataset(256)

# Initialize a Tokenizer and fit on text data
tokenizer = tf.keras.preprocessing.text.Tokenizer(oov_token='[OOV]')
tokenizer.fit_on_texts(mlm_dataset_generator.getVocubulary())

# check how many words are in the dataset (currently: 37032)
print(list(tokenizer.word_index.keys()))
# Out:
# ['[OOV]', 'and', 'to', 'of', 'the', 'for', 'in', 'number', 'with', 'a', 'management', 'on', 'as', 'all', 'sales', 'customer', 'business', 'by', 'new', 'service', 'team', 'development', 'training', 'project', 'skills', 'work', 'i', 'or', 'information', 'that', 'manager', 'marketing', 'financial', 'including', 'office', 'support', 'staff', 'experience', 'professional', 'data', 'from', 'at', 'system', 'managed', 'process', 'systems', 'quality', 'design', 'customers', 'university', 'developed', 'company', 'reports', 'clients', 'client', 'an', 'analysis', 'operations', 'product', 'high', 'other', 'maintained', 'services', 'accounts', 'program', 'responsible', 'through', 'accounting', 'microsoft', 'software', 'procedures', 'projects', 'ensure', 'planning', 'communication', 'up', 'time', 'equipment', 'performance', 'daily', 'needs', 'provided', 'my', 'school', 'issues', 'employees', 'inventory', 'well', 'media', 'technical', 'leadership', 'knowledge', 'budget', 'their', 'food', 'activities', 'created', 'over', 'using', 'education', 'department', 'programs', 'technology', 'employee', 'science', 'safety', 'health', 'various', 'control', 'relations', 'maintain', 'monthly', 'years', 'engineering', 'policies', 'such', 'administration', 'worked', 'products', 'plans', 'provide', 'production', 'reporting', 'assisted', 'students', 'account', 'research', 'excel', 'strong', 'construction', 'maintenance', 'materials', 'general', 'public', 'state', 'processes', 'was', 'goals', 'cash', 'strategic', 'within', 'events', 'community', 'based', 'implemented', 'working', 'care', 'is', 'college', 'prepared', 'it', 'develop', 'assistant', 'compliance', 'meetings', 'computer', 'which', 'are', 'personnel', 'senior', 'while', 'manage', 'excellent', 'director', 'requirements', 'human', 'network', 'plan', 'executive', 'level', 'cost', 'social', 'arts', 'managing', 'payroll', 'medical', 'records', 'relationships', 'standards', 'finance', 'lead', 'store', 'hr', 'members', 'building', 'documentation', 'market', 'performed', 'student', 'administrative', 'resources', 'member', 'strategies', 'database', 'year', 'internal', 'ability', 'key', 'problem', 'day', 'environment', 'assist', 'multiple', 'security', 'implementation', 'bachelor', 'each', 'related', 'end', 'word', 'associate', 'corporate', 'special', 'personal', 'organization', 'appropriate', 'effective', 'patient', 'specialist', 'credit', 'job', 'orders', 'organizational', 'annual', 'testing', 'review', 'have', 'center', 'organized', 'coordinated', 'use', 'revenue', 'order', 'weekly', 'be', 'communications', 'solutions', 'were', 'trained', 'areas', 'duties', 'preparation', 'applications', 'into', 'prepare', 'site', 'group', 'providing', 'conducted', 'ms', 'during', 'designed', 'create', 'learning', 'certified', 'insurance', 'needed', 'meet', 'web', 'teams', 'results', 'processing', 'scheduling', 'documents', 'strategy', 'out', 'used', 'managers', 'problems', 'tax', 'completed', 'calls', 'developing', 'them', 'delivery', 'test', 'required', 'first', 'maintaining', 'timely', 'this', 'bank', 'established', 'led', 'access', 'set', 'tools', 'one', 'effectively', 'local', 'content', 'both', 'increase', 'satisfaction', 'national', 'additional', 'retail', 'regarding', 'field', 'billing', 'line', 'e', 'benefits', 'items', 'multi', 'creative', 'any', 'help', 'more', 'application', 'improvement', 'international', 'proper', 'tasks', 'patients', 'accurate', 'contracts', 'digital', 'per', 'include', 'record', 'million', 'opportunities', 'improve', 'position', 'phone', 'c', 'positive', 'our', 'also', 'area', 'current', 'when', 'vendors', 'solving', 'between', 'included', 'presentations', 'monitored', 'fitness', 'industry', 'best', 'making', 'resource', 'etc', 'growth', 'oriented', 'necessary', 'teacher', 'levels', 'manner', 'who', 'changes', 'supervisor', 'm', 'successfully', 'coordinator', 'assigned', 'schedule', 'powerpoint', 'month', 'functions', 'healthcare', 'report', 'increased', 'direct', 'practices', 'operational', ' ...

# %%
# Usage example with original Transformer hyperparameters
num_layers = 6
d_model = 512
num_heads = 8
dff = 2048
input_vocab_size = 40000
maximum_position_encoding = 10000

model = MLMTransformerEncoder(num_layers, d_model, num_heads, dff, input_vocab_size, maximum_position_encoding)
dummy_input = [tf.keras.Input(shape=(None,)), tf.keras.Input(shape=(None,))]
model(dummy_input)

# Define an optimizer (e.g., Adam)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# Define a loss function (e.g., categorical cross-entropy for classification)
loss_function = tf.keras.losses.CategoricalCrossentropy()

# %%
import time

# Define a training loop
def train_step(inputs_batch, labels_batch):
    start_time = time.time()
    per_sequence_start_time = start_time

    total_loss = 0.0
    gradients_accumulator = [tf.zeros_like(var) for var in model.trainable_variables]

    counter = 0
    for inputs, labels in zip(inputs_batch, labels_batch):
        with tf.GradientTape() as tape:
            # create one-hot encoded mask and get the indices
            mask =[[]]
            token_indices = []
            for index, token in enumerate(inputs):
                if token == '[MASK]':
                    mask[0].append(0)
                    token_indices.append(index)
                else: 
                    mask[0].append(1)
            mask = tf.cast(mask, tf.float32)
            # tokenize inputs
            input_ids = tf.cast(tokenizer.texts_to_sequences([inputs]), tf.float32)
            # tokenize labels
            token_ids = tokenizer.texts_to_sequences(labels)
            # create array of zeroes with dimension [sequence_length, input_vocab_size]
            tokenized_labels = np.zeros((len(inputs), input_vocab_size))
            # change the [masked_token_index, token_id] to ones
            for index, token_index in enumerate(token_indices):
                tokenized_labels[token_index, token_ids[index]] = 1
            tokenized_labels = tf.constant(tokenized_labels, dtype=tf.float32)

            # print('\n> INPUTS')
            # print(input_ids)
            # print(mask)

            predictions = model([input_ids, mask], training=True)[0]

            tokenized_labels = tf.nn.softmax(tokenized_labels)
            predictions = tf.nn.softmax(predictions)

            # print('\n> LABELS')
            # print(tokenized_labels)
            # print('\n> PREDICTIONS')
            # print(predictions)

            loss = loss_function(tokenized_labels, predictions)
            # print('\n> LOSS')
            # print(loss)
        
        gradients = tape.gradient(loss, model.trainable_variables)
        # print('GRADIENTS')
        # print(gradients)

        gradients_accumulator = [grad_accum + grad for grad_accum, grad in zip(gradients_accumulator, gradients)]
        total_loss += loss

        print('Seq ' + str(counter) + ', Elapsed Time: ' + str(time.time() - per_sequence_start_time))
        per_sequence_start_time = time.time()
        counter += 1

    gradients_avg = [grad / len(inputs_batch) for grad in gradients_accumulator]
    
    optimizer.apply_gradients(zip(gradients_avg, model.trainable_variables))

    return total_loss / len(inputs_batch), str(time.time() - start_time)

# %%
# Example of usage in the training loop
num_epochs = 10
for epoch in range(num_epochs):
    batch_counter = 0
    for inputs_batch, labels_batch in mlm_dataset:  # Provide training data
        loss, elapsed_time = train_step(inputs_batch, labels_batch)
        # Log or print the loss for monitoring
        print('Epoch ' + str(epoch) + ', Batch ' + str(batch_counter) + ', Loss = ' + str(loss) + ', Elapsed Time: ' + elapsed_time)
        batch_counter += 1
# Out:
# Seq 0, Elapsed Time: 1.3892762660980225
# Seq 1, Elapsed Time: 1.013577938079834
# Seq 2, Elapsed Time: 1.2359111309051514
# Seq 3, Elapsed Time: 1.0576038360595703
# Seq 4, Elapsed Time: 0.8138155937194824
# Seq 5, Elapsed Time: 0.8039431571960449
# Seq 6, Elapsed Time: 0.7999587059020996
# Seq 7, Elapsed Time: 0.8213064670562744
# Seq 8, Elapsed Time: 0.8163027763366699
# Seq 9, Elapsed Time: 0.8003222942352295
# Seq 10, Elapsed Time: 0.8403520584106445
# Seq 11, Elapsed Time: 0.8280596733093262
# Seq 12, Elapsed Time: 0.9115438461303711
# Seq 13, Elapsed Time: 0.8644077777862549
# Seq 14, Elapsed Time: 0.9649076461791992
# Seq 15, Elapsed Time: 0.822723388671875
# Seq 16, Elapsed Time: 0.8256533145904541
# Seq 17, Elapsed Time: 0.8278286457061768
# Seq 18, Elapsed Time: 1.0708527565002441
# Seq 19, Elapsed Time: 0.8761017322540283
# Seq 20, Elapsed Time: 0.8139517307281494
# Seq 21, Elapsed Time: 1.040633201599121
# Seq 22, Elapsed Time: 0.8638637065887451
# Seq 23, Elapsed Time: 1.151839017868042
# Seq 24, Elapsed Time: 0.8988528251647949
# Seq 25, Elapsed Time: 1.0322456359863281
# Seq 26, Elapsed Time: 0.825852632522583
# Seq 27, Elapsed Time: 0.9126670360565186
# Seq 28, Elapsed Time: 0.9115686416625977
# Seq 29, Elapsed Time: 0.9228372573852539
# Seq 30, Elapsed Time: 0.911632776260376
# Seq 31, Elapsed Time: 0.9101753234863281
# Seq 32, Elapsed Time: 0.802452564239502
# Seq 33, Elapsed Time: 0.9812557697296143
# Seq 34, Elapsed Time: 1.1733696460723877
# Seq 35, Elapsed Time: 1.1036486625671387
# Seq 36, Elapsed Time: 0.8639190196990967
# Seq 37, Elapsed Time: 0.96561598777771
# Seq 38, Elapsed Time: 1.041879415512085
# Seq 39, Elapsed Time: 0.9018192291259766
# Seq 40, Elapsed Time: 0.9254188537597656
# Seq 41, Elapsed Time: 0.9815511703491211
# Seq 42, Elapsed Time: 0.8722245693206787
# Seq 43, Elapsed Time: 0.9014842510223389
# Seq 44, Elapsed Time: 0.8804121017456055
# Seq 45, Elapsed Time: 0.9180762767791748
# Seq 46, Elapsed Time: 0.895165205001831
# Seq 47, Elapsed Time: 0.8333849906921387
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14804\3465716743.py in ?()
#       3 # Example of usage in the training loop
#       4 num_epochs = 10
#       5 for epoch in range(num_epochs):
# ----> 6     batch_counter = 0
#       7     for inputs_batch, labels_batch in mlm_dataset:  # Provide training data
#       8         loss, elapsed_time = train_step(inputs_batch, labels_batch)
#       9         # Log or print the loss for monitoring
#
# ~\AppData\Local\Temp\ipykernel_14804\1285950202.py in ?(inputs_batch, labels_batch)
#      53         gradients = tape.gradient(loss, model.trainable_variables)
#      54         # print('GRADIENTS')
#      55         # print(gradients)
#      56
# ---> 57         gradients_accumulator = [grad_accum + grad for grad_accum, grad in zip(gradients_accumulator, gradients)]
#      58         total_loss += loss
#      59
#      60         print('Seq ' + str(counter) + ', Elapsed Time: ' + str(time.time() - per_sequence_start_time))
#
# ~\AppData\Local\Temp\ipykernel_14804\1285950202.py in ?(.0)
# ---> 57 def train_step(inputs_batch, labels_batch):
#      58     start_time = time.time()
#      59     per_sequence_start_time = start_time
#      60
#
# d:\Applications\Python\Python39\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# d:\Applications\Python\Python39\lib\site-packages\tensorflow\python\ops\math_ops.py in ?(x, y)
#    1491             return out
#    1492           except (TypeError, ValueError):
#    1493             raise e
#    1494         else:
# -> 1495           raise
#
# d:\Applications\Python\Python39\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# d:\Applications\Python\Python39\lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#    1265         if result is not OpDispatcher.NOT_SUPPORTED:
#    1266           return result
#    1267         else:
# -> 1268           raise
#
# d:\Applications\Python\Python39\lib\site-packages\tensorflow\python\ops\math_ops.py in ?(x, y, name)
#    1864       and not isinstance(y, tensor_lib.Tensor)
#    1865       and not isinstance(y, sparse_tensor.SparseTensor)
#    1866   ):
#    1867     y = ops.convert_to_tensor(y, dtype_hint=x.dtype.base_dtype, name="y")
# -> 1868   return add(x, y, name=name)
#
# d:\Applications\Python\Python39\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# d:\Applications\Python\Python39\lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#    1265         if result is not OpDispatcher.NOT_SUPPORTED:
#    1266           return result
#    1267         else:
# -> 1268           raise
#
# d:\Applications\Python\Python39\lib\site-packages\tensorflow\python\ops\math_ops.py in ?(x, y, name)
#    4091     y = ops.convert_to_tensor(y, dtype_hint=x.dtype.base_dtype, name="y")
#    4092     if x.dtype == dtypes.string:
#    4093       return gen_math_ops.add(x, y, name=name)
#    4094     else:
# -> 4095       return gen_math_ops.add_v2(x, y, name=name)
#
# d:\Applications\Python\Python39\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in ?(x, y, name)
#     507       return _result
#     508     except _core._NotOkStatusException as e:
#     509       _ops.raise_from_not_ok_status(e, name)
#     510     except _core._FallbackException:
# --> 511       pass
#     512     try:
#     513       return add_v2_eager_fallback(
#     514           x, y, name=name, ctx=_ctx)
#
# KeyboardInterrupt:
